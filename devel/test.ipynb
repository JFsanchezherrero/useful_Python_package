# %%
import UPyPac

# %%
from UPyPac.functions import aesthetics_functions

# %%
aesthetics_functions.pipeline_header("RSP")
# Out:
# ######################################################################
# #                       RNAseq pipeline - RSP                        #
# #            Jose F. Sanchez, Mireia Marin & Lauro Sumoy             #
# #        Copyright (C) 2019-2024 Lauro Sumoy Lab, IGTP, Spain        #
# ######################################################################
